# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow===2.10.0
# !pip install torch
# !pip install keras===2.10.0
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# added to avoid warnings: Please update jupyter and ipywidgets
# !pip install ipywidgets
#!pip install tf-keras
# Out:
# Collecting tensorflow===2.10.0
#   Using cached tensorflow-2.10.0-cp39-cp39-macosx_10_14_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (3.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (3.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (23.2)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow===2.10.0)
#   Using cached protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl.metadata (787 bytes)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.62.1)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow===2.10.0)
#   Using cached tensorboard-2.10.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (2.10.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow===2.10.0)
#   Using cached keras-2.10.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow===2.10.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.17.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.2.2)
# Using cached tensorflow-2.10.0-cp39-cp39-macosx_10_14_x86_64.whl (241.2 MB)
# Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# Using cached protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl (980 kB)
# Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Installing collected packages: keras, tensorboard-data-server, protobuf, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 3.1.1
#     Uninstalling keras-3.1.1:
#       Successfully uninstalled keras-3.1.1
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.1
#     Uninstalling tensorflow-2.16.1:
#       Successfully uninstalled tensorflow-2.16.1
# Successfully installed keras-2.10.0 protobuf-3.19.6 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorflow-2.10.0
# Requirement already satisfied: torch in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: keras===2.10.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (2.10.0)
# Requirement already satisfied: transformers in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (4.39.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: datasets in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (2.18.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (0.21.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: evaluate in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (0.4.1)
# Requirement already satisfied: datasets>=2.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2.18.0)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (4.66.2)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.2.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.21.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (23.2)
# Requirement already satisfied: responses<0.19 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (4.66.2)
# Requirement already satisfied: rouge_score in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (2023.12.25)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (4.66.2)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: backcall in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
